# %% [markdown]
# # Phase 1: Problem Definition & Data Understanding
# ## Expresso Customer Churn Prediction System
#
# **Objective**: Define the business problem, success criteria, and approach for predicting customer churn
#
# **Constitutional Principles Applied**:
# - Data-First Development: Understanding data requirements upfront
# - Business Impact Focus: Clear ROI and retention strategy definition
# - Validation-Driven Modeling: Establishing evaluation criteria

# %% [markdown]
# ## 1. Business Problem Definition
#
# ### Background
# Expresso is a telecommunications company facing customer churn challenges that impact revenue and growth. Customer acquisition costs are significantly higher than retention costs, making churn prediction a critical business priority.
#
# ### Problem Statement
# **Primary Question**: Can we predict which customers are likely to churn within the next 60 days with >85% accuracy?
#
# **Secondary Questions**:
# - What are the key factors driving customer churn?
# - Which customer segments are most at risk?
# - What retention strategies would be most effective?
# - What is the potential business impact of successful prediction?

# %% [markdown]
# ## 2. Success Criteria
#
# ### Model Performance Targets
# - **Primary Metric**: F1-Score ≥ 0.85 (balanced precision/recall for imbalanced data)
# - **Secondary Metrics**:
#   - AUC-ROC ≥ 0.80
#   - Precision ≥ 0.80 (minimize false positives)
#   - Recall ≥ 0.75 (capture most churners)
#
# ### Business Impact Targets
# - Identify top 20% of at-risk customers
# - Enable 15%+ improvement in retention rate
# - Generate positive ROI within 6 months
# - Provide actionable insights for customer success teams

# %% [markdown]
# ## 3. Technical Approach
#
# ### Methodology
# - **Framework**: CRISP-DM (Cross-Industry Standard Process for Data Mining)
# - **Validation**: Stratified K-Fold Cross-Validation (K=5)
# - **Class Imbalance**: SMOTE (Synthetic Minority Over-sampling Technique)
# - **Feature Engineering**: Business-interpretable derived metrics
#
# ### Technology Stack
# - **Core**: Python 3.11+, pandas, numpy, scikit-learn
# - **Visualization**: seaborn, matplotlib (constitutional requirement)
# - **Experiment Tracking**: MLflow
# - **Development**: Jupyter notebooks + modular Python services
# - **Testing**: pytest with contract-driven TDD

# %% [markdown]
# ## 4. Data Understanding Framework
#
# ### Expected Data Sources
# 1. **Customer Demographics**: Age, gender, location, account type
# 2. **Usage Patterns**: Call frequency, data usage, SMS volume
# 3. **Service History**: Tenure, service changes, upgrades
# 4. **Billing Information**: Payment method, bill amount, payment history
# 5. **Support Interactions**: Call center contacts, complaint history
# 6. **Churn Events**: Binary target variable (0=No Churn, 1=Churn)
#
# ### Data Quality Requirements
# - Missing values < 20% per feature
# - Class imbalance ratio documented and handled
# - Feature correlation analysis completed
# - Outlier detection and treatment strategy defined

# %% [markdown]
# ## 5. Project Timeline & Milestones
#
# ### Phase Breakdown (6 Phases)
# 1. **Problem Definition** (Current) - 3 days
# 2. **Data Loading & Validation** - 2 days
# 3. **Preprocessing & Feature Engineering** - 5 days
# 4. **Exploratory Data Analysis** - 4 days
# 5. **Model Development & Evaluation** - 7 days
# 6. **Business Impact Analysis** - 4 days
#
# ### Key Deliverables
# - ✅ Contract tests (TDD compliance)
# - ✅ Data models and entity definitions
# - 📋 Jupyter notebooks for each phase
# - 📋 MLflow experiment tracking
# - 📋 Executive summary and recommendations

# %% [markdown]
# ## 6. Risk Assessment & Mitigation
#
# ### Technical Risks
# | Risk | Impact | Probability | Mitigation |
# |------|--------|-------------|------------|
# | Poor data quality | High | Medium | Comprehensive validation & cleaning pipeline |
# | Class imbalance | High | High | SMOTE + stratified sampling |
# | Overfitting | Medium | Medium | Nested cross-validation |
# | Feature leakage | High | Low | Temporal validation & business logic review |
#
# ### Business Risks
# | Risk | Impact | Probability | Mitigation |
# |------|--------|-------------|------------|
# | Low model adoption | High | Medium | Stakeholder involvement + interpretability |
# | Insufficient ROI | Medium | Low | Conservative business case + phased rollout |
# | Data privacy concerns | High | Low | Anonymization + compliance review |

# %% [markdown]
# ## 7. Ethical Considerations
#
# ### Fairness & Bias
# - Ensure predictions don't discriminate based on protected characteristics
# - Monitor model performance across customer segments
# - Regular bias audits and model retraining
#
# ### Privacy & Transparency
# - Customer data anonymization and secure handling
# - Explainable AI for retention strategy recommendations
# - Clear communication about data usage for churn prediction

# %% [markdown]
# ## 8. Next Steps
#
# ### Immediate Actions
# 1. **Data Loading**: Set up data pipeline and initial validation
# 2. **Quality Assessment**: Run comprehensive data quality checks
# 3. **Baseline Model**: Establish simple benchmark for comparison
# 4. **MLflow Setup**: Initialize experiment tracking
#
# ### Phase 2 Preparation
# - Review data loading contracts and validation rules
# - Prepare data quality assessment framework
# - Set up reproducible random seeds (42) for consistency
# - Initialize MLflow experiment: 'expresso-churn-prediction'

# %%
# Environment setup for Phase 1
import sys
import os
from datetime import datetime

# Add project root to path
sys.path.append(os.path.abspath('..'))

# Set reproducibility seed
RANDOM_SEED = 42

# Project configuration
PROJECT_NAME = "Expresso Customer Churn Prediction"
ANALYSIS_DATE = datetime.now().strftime("%Y-%m-%d")
PREDICTION_WINDOW = 60  # days

print(f"📊 {PROJECT_NAME}")
print(f"📅 Analysis Date: {ANALYSIS_DATE}")
print(f"⏰ Prediction Window: {PREDICTION_WINDOW} days")
print(f"🎲 Random Seed: {RANDOM_SEED}")
print("\n✅ Phase 1: Problem Definition Complete")
print("➡️  Ready for Phase 2: Data Loading & Validation")
